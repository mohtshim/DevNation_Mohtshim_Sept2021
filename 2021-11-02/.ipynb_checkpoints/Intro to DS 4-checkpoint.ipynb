# %% [markdown]
# # Question no 1

# %%
import pandas as pd
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
game_data = pd.read_csv("Copy of super_bowls.csv")
game_data.head()
# Out:
#          date  super_bowl                          venue             city  \
# 0  2018-02-04          52              U.S. Bank Stadium      Minneapolis
# 1  2017-02-05          51                    NRG Stadium          Houston
# 2  2016-02-07          50                 Levi's Stadium      Santa Clara
# 3  2015-02-01          49  University of Phoenix Stadium         Glendale
# 4  2014-02-02          48                MetLife Stadium  East Rutherford
#
#         state  attendance           team_winner  winning_pts     qb_winner_1  \
# 0   Minnesota       67612   Philadelphia Eagles           41      Nick Foles
# 1       Texas       70807  New England Patriots           34       Tom Brady
# 2  California       71088        Denver Broncos           24  Peyton Manning
# 3     Arizona       70288  New England Patriots           28       Tom Brady
# 4  New Jersey       82529      Seattle Seahawks           43  Russell Wilson
#
# ...

# %%
tv_data = pd.read_csv("Copy of tv.csv")
tv_data.head()
# Out:
#    super_bowl network  avg_us_viewers  total_us_viewers  rating_household  \
# 0          52     NBC       103390000               NaN              43.1
# 1          51     Fox       111319000       172000000.0              45.3
# 2          50     CBS       111864000       167000000.0              46.6
# 3          49     NBC       114442000       168000000.0              47.5
# 4          48     Fox       112191000       167000000.0              46.7
#
#    share_household  rating_18_49  share_18_49  ad_cost
# 0               68          33.4         78.0  5000000
# 1               73          37.1         79.0  5000000
# 2               72          37.7         79.0  5000000
# 3               71          39.1         79.0  4500000
# 4               69          39.3         77.0  4000000

# %%
musician_data = pd.read_csv("Copy of halftime_musicians.csv")
musician_data.head()
# Out:
#    super_bowl                               musician  num_songs
# 0          52                      Justin Timberlake       11.0
# 1          52  University of Minnesota Marching Band        1.0
# 2          51                              Lady Gaga        7.0
# 3          50                               Coldplay        6.0
# 4          50                                Beyoncé        3.0

# %% [markdown]
# # Question no 2

# %%
tv_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   super_bowl        53 non-null     int64
#  1   network           53 non-null     object
#  2   avg_us_viewers    53 non-null     int64
#  3   total_us_viewers  15 non-null     float64
#  4   rating_household  53 non-null     float64
#  5   share_household   53 non-null     int64
#  6   rating_18_49      15 non-null     float64
#  7   share_18_49       6 non-null      float64
#  8   ad_cost           53 non-null     int64
# dtypes: float64(4), int64(4), object(1)
# memory usage: 3.9+ KB

# %%
musician_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   super_bowl  134 non-null    int64
#  1   musician    134 non-null    object
#  2   num_songs   88 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 3.3+ KB

# %% [markdown]
# # Question no 3

# %%
import numpy as np
import matplotlib.pyplot as plt
x_axis = game_data["super_bowl"]
y_axis = game_data["combined_pts"]
superbowl = np.array(x_axis)
combinedpoints = np.array(y_axis)
xmax = superbowl[np.argmax(combinedpoints)]
ymax = y.max()
xmin = superbowl[np.argmin(combinedpoints)]
ymin = y.min()
plt.plot(superbowl,combinedpoints)
plt.annotate("Highest", xy = (xmax,ymax))
plt.annotate("Lowest", xy = (xmin,ymin))
plt.xlabel("Super_Bowls")
plt.ylabel("Combined_pts")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Question no 4

# %%
import numpy as np
import matplotlib.pyplot as plt
x_axis = game_data["super_bowl"]
y_axis = game_data["difference_pts"]
superbowl = np.array(x_axis)
difference_pts = np.array(y_axis)
plt.plot(superbowl,difference_pts)
plt.xlabel("Super_Bowls")
plt.ylabel("difference_pts")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Question no 5

# %%
game_data
tv_data
df = game_data.merge(tv_data,how = 'outer', on = 'super_bowl')
df = df.merge(musician_data,how = 'outer',on = 'super_bowl')
df
# Out:
#            date  super_bowl                          venue             city  \
# 0    2018-02-04          52              U.S. Bank Stadium      Minneapolis
# 1    2018-02-04          52              U.S. Bank Stadium      Minneapolis
# 2    2017-02-05          51                    NRG Stadium          Houston
# 3    2016-02-07          50                 Levi's Stadium      Santa Clara
# 4    2016-02-07          50                 Levi's Stadium      Santa Clara
# 5    2016-02-07          50                 Levi's Stadium      Santa Clara
# 6    2016-02-07          50                 Levi's Stadium      Santa Clara
# 7    2016-02-07          50                 Levi's Stadium      Santa Clara
# 8    2016-02-07          50                 Levi's Stadium      Santa Clara
# 9    2016-02-07          50                 Levi's Stadium      Santa Clara
# 10   2015-02-01          49  University of Phoenix Stadium         Glendale
# ...

# %%
x_axis = df["share_household"]
y_axis = df["difference_pts"]
share_household = np.array(x_axis)
difference_pts = np.array(y_axis)
plt.bar(share_household,difference_pts)
plt.xlabel("share_household")
plt.ylabel("difference_pts")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Question no 6

# %%
x_axis = df["super_bowl"]
y_axis = df["total_us_viewers"]
super_bowl = np.array(x_axis)
total_us_viewers = np.array(y_axis)
plt.plot(super_bowl,total_us_viewers)
plt.xlabel("super_bowl")
plt.ylabel("total_us_viewers")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x_axis = df["super_bowl"]
y_axis = df["rating_household"]
super_bowl = np.array(x_axis)
rating_household = np.array(y_axis)
plt.plot(super_bowl,rating_household)
plt.xlabel("super_bowl")
plt.ylabel("rating_household")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Question no 8

# %%
musician_data[musician_data.duplicated('musician',keep = False)]
# Out:
#      super_bowl                                           musician  num_songs
# 0            52                                  Justin Timberlake       11.0
# 1            52              University of Minnesota Marching Band        1.0
# 4            50                                            Beyoncé        3.0
# 5            50                                         Bruno Mars        3.0
# 14           48                                         Bruno Mars        6.0
# 16           47                                            Beyoncé        7.0
# 34           41           Florida A&M University Marching 100 Band        NaN
# 40           38                                              Nelly        1.0
# 42           38                                  Justin Timberlake        1.0
# 53           35                                              Nelly        1.0
# 58           33                                     Gloria Estefan        3.0
# ...

# %% [markdown]
# # Question no 9

# %%
pattern = 'Marching|Spirit'
mask = musician_data['musician'].str.contains(pattern, case=False, na=False)
data = musician_data[mask]
data[data['super_bowl'] > 20]
# Out:
#     super_bowl                                          musician  num_songs
# 1           52             University of Minnesota Marching Band        1.0
# 7           50            University of California Marching Band        3.0
# 13          49  Arizona State University Sun Devil Marching Band        NaN
# 34          41          Florida A&M University Marching 100 Band        NaN
# 43          38                   The Ocean of Soul Marching Band        NaN
# 44          38        The Spirit of Houston Cougar Marching Band        NaN
# 66          32    Grambling State University Tiger Marching Band        1.0
# 82          26             University of Minnesota Marching Band        NaN
# 87          24                   Pride of Nicholls Marching Band        NaN
# 92          22        San Diego State University Marching Aztecs        NaN
# 93          22                                    Spirit of Troy        NaN
# ...
