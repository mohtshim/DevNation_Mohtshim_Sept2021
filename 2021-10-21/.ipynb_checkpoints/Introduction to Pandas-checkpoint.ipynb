# %%
import pandas as pd
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

df = pd.read_csv('Copy of olympics.csv',index_col = 0, skiprows = 1)

for col in df.columns:
    if col[:2] == '01':
        df.rename(columns = {col:'Gold'+col[4:]},inplace = True)
    if col[:2] == '02':
        df.rename(columns = {col:'Silver'+col[4:]},inplace = True)
    if col[:2] == '03':
        df.rename(columns = {col:'Bronze'+col[4:]},inplace = True)
    if col[:1] == '№':
        df.rename(columns = {col:'#'+col[1:]},inplace = True)

names_ids = df.index.str.split('\s\(')

df.index = names_ids.str[0]
df['ID'] = names_ids.str[1].str[:3]

df = df.drop('Totals')
print(df)
# Out:
#                                   # Summer  Gold  Silver  Bronze  Total  \
# Afghanistan                             13     0       0       2      2
# Algeria                                 12     5       2       8     15
# Argentina                               23    18      24      28     70
# Armenia                                  5     1       2       9     12
# Australasia                              2     3       4       5     12
# Australia                               25   139     152     177    468
# Austria                                 26    18      33      35     86
# Azerbaijan                               5     6       5      15     26
# Bahamas                                 15     5       2       5     12
# Bahrain                                  8     0       0       1      1
# Barbados                                11     0       0       1      1
# Belarus                                  5    12      24      39     75
# ...

# %% [markdown]
# # Question no 0

# %%
def first_country(df):
    country_series = pd.Series(df.loc['Afghanistan'])
    print()
    return country_series
first_country(df)
# Out:
# # Summer           13
# Gold                0
# Silver              0
# Bronze              2
# Total               2
# # Winter            0
# Gold.1              0
# Silver.1            0
# Bronze.1            0
# Total.1             0
# # Games            13
# Gold.2              0
# Silver.2            0
# Bronze.2            2
# Combined total      2
# ID                AFG
# Name: Afghanistan, dtype: object

# %% [markdown]
# # Question no 1

# %%
def country_with_most_Gold():
    df['difference'] = df["Gold"]-df["Gold.1"]
    index = df['difference'].argmax()
    a = df.iloc[index]
    print(a['ID'])
country_with_most_Gold()
# Out:
# USA

# %% [markdown]
# # Question no 2

# %%
def Gold_difference():
    new_df = df[['Gold','Gold.1']]
    values = (new_df != 0).any(axis=1)
    new_df = new_df.loc[values]
    new_df['Total'] = new_df['Gold'] + new_df['Gold.1']
    new_df['Gold_Difference'] = (new_df['Gold']-new_df['Gold.1']) /new_df['Total'] 
    print(new_df)
    arr = new_df[new_df['Gold_Difference']==new_df['Gold_Difference'].max()].index.values
    print("The most Gold medal Difference country is "+ arr[0])
Gold_difference()
# Out:
#                         Gold  Gold.1  Total  Gold_Difference
# Algeria                    5       0      5         1.000000
# Argentina                 18       0     18         1.000000
# Armenia                    1       0      1         1.000000
# Australasia                3       0      3         1.000000
# Australia                139       5    144         0.930556
# Austria                   18      59     77        -0.532468
# Azerbaijan                 6       0      6         1.000000
# Bahamas                    5       0      5         1.000000
# Belarus                   12       6     18         0.333333
# Belgium                   37       1     38         0.947368
# Brazil                    23       0     23         1.000000
# Bulgaria                  51       1     52         0.961538
# Burundi                    1       0      1         1.000000
# Cameroon                   3       0      3         1.000000
# ...
